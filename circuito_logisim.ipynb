# %% [markdown]
# ## MEMORIA ROM COM 2 BITS DE ENDEREÇO E 4 BITS POR CÉLULA
#
# 1. Endereço 00:
#
# ![image.png](attachment:image.png)
#
# _OUTPUT: 0101_
#
# 2. Endereço 01:
#
# ![image-2.png](attachment:image-2.png)
#
# _OUTPUT: 1011_
#
# 3. Endereço 10:
#
# ![image-3.png](attachment:image-3.png)
#
# _OUTPUT: 1110_
